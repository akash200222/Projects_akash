# %%
# we import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.express as px
import plotly.graph_objects as go
# Out:
# C:\Users\AKASH\anac\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Load the data of virat kohli performance and read the file
data = pd.read_csv("C:\\Users\\AKASH\\OneDrive\\Desktop\\ML\\virat_data.csv")
data
# Out:
#      index  runs  opponent        ground        date match  Match_No  total
# 0        0    12  SriLanka      Dambulla  18-08-2008   ODI         1     12
# 1        1    37  SriLanka      Dambulla  20-08-2008   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)  24-08-2008   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)  27-08-2008   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)  29-08-2008   ODI         5    159
# ..     ...   ...       ...           ...         ...   ...       ...    ...
# 511    535    11   England    Birmingham  01-07-2022  Test       512  23661
# 512    536    20   England    Birmingham  01-07-2022  Test       513  23681
# 513    537     1   England    Birmingham  09-07-2022   T20       514  23682
# 514    538    11   England    Nottingham  10-07-2022   T20       515  23693
# 515    539    16   England        Lord's  14-07-1905   ODI       516  23709
#
# [516 rows x 8 columns]

# %%
# extrect the columns of the data 
data.columns
for i in data.columns:
    print(i)
# Out:
# index
# runs
# opponent
# ground
# date
# match
# Match_No
# total

# %%
# extrect the Types of data 
data.dtypes
# Out:
# index        int64
# runs         int64
# opponent    object
# ground      object
# date        object
# match       object
# Match_No     int64
# total        int64
# dtype: object

# %%
# show the top 5 rows and columns 
data.head()
# Out:
#    index  runs  opponent        ground        date match  Match_No  total
# 0      0    12  SriLanka      Dambulla  18-08-2008   ODI         1     12
# 1      1    37  SriLanka      Dambulla  20-08-2008   ODI         2     49
# 2      2    25  SriLanka  Colombo(RPS)  24-08-2008   ODI         3     74
# 3      3    54  SriLanka  Colombo(RPS)  27-08-2008   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)  29-08-2008   ODI         5    159

# %%
# show the lower 5 data 
data.tail()
# Out:
#      index  runs opponent      ground        date match  Match_No  total
# 511    535    11  England  Birmingham  01-07-2022  Test       512  23661
# 512    536    20  England  Birmingham  01-07-2022  Test       513  23681
# 513    537     1  England  Birmingham  09-07-2022   T20       514  23682
# 514    538    11  England  Nottingham  10-07-2022   T20       515  23693
# 515    539    16  England      Lord's  14-07-1905   ODI       516  23709

# %%
# to show the total rows and columns
data.shape
# Out:
# (516, 8)

# %%
# To get the all informant about the data set 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     516 non-null    int64
#  1   runs      516 non-null    int64
#  2   opponent  516 non-null    object
#  3   ground    516 non-null    object
#  4   date      516 non-null    object
#  5   match     516 non-null    object
#  6   Match_No  516 non-null    int64
#  7   total     516 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 32.4+ KB

# %%
#Get Overall Statistics About The Dataframe with Describe method 
data.describe()
# Out:
#             index        runs    Match_No         total
# count  516.000000  516.000000  516.000000    516.000000
# mean   270.118217   45.947674  258.500000  11681.726744
# std    155.219618   44.584372  149.100637   7301.114849
# min      0.000000    0.000000    1.000000     12.000000
# 25%    134.750000   11.000000  129.750000   5328.250000
# 50%    270.500000   32.500000  258.500000  10886.500000
# 75%    403.250000   70.250000  387.250000  18535.750000
# max    539.000000  254.000000  516.000000  23709.000000

# %%
#Describe only sauch columns
data[['runs']].describe()
# Out:
#              runs
# count  516.000000
# mean    45.947674
# std     44.584372
# min      0.000000
# 25%     11.000000
# 50%     32.500000
# 75%     70.250000
# max    254.000000

# %%
# this function use to find the duplicated values
data.duplicated(keep = False).sum()
# Out:
# 0

# %%
# this function to use the find the null values in data set
data.isnull().sum()
# Out:
# index       0
# runs        0
# opponent    0
# ground      0
# date        0
# match       0
# Match_No    0
# total       0
# dtype: int64

# %%
#droup the unwanted columns. we used droup function 
data.drop(["date","Match_No"],axis = 1, inplace = True)

# %%
data
# Out:
#      index  runs  opponent        ground match  total
# 0        0    12  SriLanka      Dambulla   ODI     12
# 1        1    37  SriLanka      Dambulla   ODI     49
# 2        2    25  SriLanka  Colombo(RPS)   ODI     74
# 3        3    54  SriLanka  Colombo(RPS)   ODI    128
# 4        4    31  SriLanka  Colombo(RPS)   ODI    159
# ..     ...   ...       ...           ...   ...    ...
# 511    535    11   England    Birmingham  Test  23661
# 512    536    20   England    Birmingham  Test  23681
# 513    537     1   England    Birmingham   T20  23682
# 514    538    11   England    Nottingham   T20  23693
# 515    539    16   England        Lord's   ODI  23709
#
# [516 rows x 6 columns]

# %%
# if we want to change any columns name 
data.rename(columns={'opponent':'opponents'})
# Out:
#      index  runs opponents        ground match  total
# 0        0    12  SriLanka      Dambulla   ODI     12
# 1        1    37  SriLanka      Dambulla   ODI     49
# 2        2    25  SriLanka  Colombo(RPS)   ODI     74
# 3        3    54  SriLanka  Colombo(RPS)   ODI    128
# 4        4    31  SriLanka  Colombo(RPS)   ODI    159
# ..     ...   ...       ...           ...   ...    ...
# 511    535    11   England    Birmingham  Test  23661
# 512    536    20   England    Birmingham  Test  23681
# 513    537     1   England    Birmingham   T20  23682
# 514    538    11   England    Nottingham   T20  23693
# 515    539    16   England        Lord's   ODI  23709
#
# [516 rows x 6 columns]

# %%
# Total runs made by virat kohli in All Formate 
sum(data.runs)
# Out:
# 23709

# %%
# highest score of Virat Kohli performance 
data.sort_values('runs').max()
# Out:
# index              539
# runs               254
# opponent      Zimbabwe
# ground      Wellington
# match             Test
# total            23709
# dtype: object

# %%
plt.pie(data["match"].value_counts(),labels=data["match"].value_counts().index, autopct="%0.1f%%",explode=[0.1,0,0])
plt.show()
# This chart shows that Virat Kohli has played most ODI matches.

# %%
# create count plot for analysis the how many grounds did Virat Kohli play matches
plt.figure(figsize=(18,5))
sns.countplot(data["ground"])
plt.xticks(rotation=80)
plt.show()
#This chat shows that Virat Kohli has played maximum number of matches in Mirpur.
# Out:
# C:\Users\AKASH\anac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# in this countplot shows virat kohli has played against which opeanent
plt.figure(figsize=(10,5))
sns.countplot(data["opponent"])
plt.xticks(rotation=80)
plt.show()
#This chart shows that Virat Kohli has played the maximum number of matches against England.
# Out:
# C:\Users\AKASH\anac\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# create barplot for analysis the In which ground did Virat Kohli score how many runs.
plt.figure(figsize=(18,15))
sns.barplot(x="ground",y="runs", data=data)
plt.xticks(rotation=100)
plt.show()

# %%
#this barplot shows Virat Kohli has scored how many runs against which opponent
plt.figure(figsize=(7,5))
sns.barplot(x="opponent",y="runs" ,  data=data)
plt.xticks(rotation=100)
plt.show()
#This chart shows that Virat Kohli scored the most runs against Afghanistan.

# %%
#This barplot divides the number of matches in which Virat Kohli has scored the most runs.
plt.figure(figsize=(7,5))
sns.barplot(x="match",y="runs" ,data=data)
plt.xticks(rotation=100)
plt.show()
#This bar chart shows that Virat Kohli has scored the most runs in ODIs and the least in T20s.

# %%
# most runs is matches 
data1 = data.groupby(['runs'],as_index =False)['match'].sum().sort_values(by = 'runs',ascending = False).head(5)
plt.figure(figsize=(10,5))
sns.countplot(data=data1, x = "match" ,hue = "runs")
plt.show()
#This column chart shows the top 5 batting performances of Virat Kohli
